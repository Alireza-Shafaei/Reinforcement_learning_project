# %%
import gym
import pygame
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = "MountainCar-v0"

# %%
env = gym.make(environment_name,  render_mode="human")

# %%
episodes = 5
state = env.reset()
env.action_space.sample()
env.step(1)
print(env.action_space.sample())
print(env.step(1))
for episode in range(1, episodes+1):
    state = env.reset()
    done0 = False
    done1 = False
    score = 0 
    
    while not (done0 or done1):
        env.render()
        action = env.action_space.sample()
        n_state, reward, done0, done1, info = env.step(action)
        score+=reward
        #env.render()
    print('Episode:{} Score:{}'.format(episode, score))
#env.close()
# Out:
# C:\Users\Asus\AppData\Roaming\Python\Python310\site-packages\gym\utils\passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# 0
# (array([-0.41274375, -0.00166178], dtype=float32), -1.0, False, False, {})
# Episode:1 Score:-200.0
# Episode:2 Score:-200.0
# Episode:3 Score:-200.0
# Episode:4 Score:-200.0
# Episode:5 Score:-200.0

# %%
env.close()

# %%
env.action_space.sample()
# Out:
# 2

# %%
env.observation_space.sample()
# Out:
# array([-0.5184865 , -0.04779657], dtype=float32)

# %%
from stable_baselines3 import DQN

# %%
import gymnasium as gym

# %%
environment_name = "MountainCar-v0"

# %%
env = gym.make(environment_name, render_mode="human")
#env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1, learning_rate=0.01)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=40000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 200      |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 29       |
# |    iterations      | 1        |
# |    time_elapsed    | 68       |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | -191        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 2           |
# |    time_elapsed         | 139         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014165392 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.909      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.951       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 11.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | -180        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 3           |
# |    time_elapsed         | 209         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009197803 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.853       |
# |    learning_rate        | 0.01        |
# |    loss                 | 4.45        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00365    |
# |    value_loss           | 11.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | -179        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 4           |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.007537987 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.746      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.96        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 10          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | -173        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 5           |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.012599478 |
# |    clip_fraction        | 0.0998      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.675      |
# |    explained_variance   | 0.964       |
# |    learning_rate        | 0.01        |
# |    loss                 | 8.85        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00507    |
# |    value_loss           | 14          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 169         |
# |    ep_rew_mean          | -169        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 6           |
# |    time_elapsed         | 420         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015706623 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.88        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00236    |
# |    value_loss           | 3.35        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 167         |
# |    ep_rew_mean          | -167        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 7           |
# |    time_elapsed         | 490         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.034368217 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.837       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 2.64        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 165         |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 8           |
# |    time_elapsed         | 560         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011573938 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.972       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.805       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00111     |
# |    value_loss           | 4.3         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 159         |
# |    ep_rew_mean          | -159        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 9           |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.035826303 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.557      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.958       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 2.22        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | -151        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 10          |
# |    time_elapsed         | 701         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.025088644 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.48       |
# |    explained_variance   | 0.986       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.99        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | 0.00685     |
# |    value_loss           | 3.04        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -147        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 11          |
# |    time_elapsed         | 772         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.022755142 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.993       |
# |    learning_rate        | 0.01        |
# |    loss                 | 0.568       |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00359     |
# |    value_loss           | 1.95        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 144        |
# |    ep_rew_mean          | -144       |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 12         |
# |    time_elapsed         | 842        |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.13235179 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.351     |
# |    explained_variance   | 0.985      |
# |    learning_rate        | 0.01       |
# |    loss                 | 0.827      |
# |    n_updates            | 310        |
# |    policy_gradient_loss | 0.0227     |
# |    value_loss           | 1.14       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | -143        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 13          |
# |    time_elapsed         | 912         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006429227 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.321      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.62        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 1.96        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 14          |
# |    time_elapsed         | 983         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015343607 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.286      |
# |    explained_variance   | 0.973       |
# |    learning_rate        | 0.01        |
# |    loss                 | 2.94        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00241    |
# |    value_loss           | 7.81        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 15          |
# |    time_elapsed         | 1053        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008778563 |
# |    clip_fraction        | 0.0669      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.4         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | 0.000566    |
# |    value_loss           | 9.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 138         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 16          |
# |    time_elapsed         | 1124        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.077235654 |
# |    clip_fraction        | 0.0812      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.01        |
# |    loss                 | 1.65        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.0022      |
# |    value_loss           | 4.29        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 140          |
# |    ep_rew_mean          | -140         |
# | time/                   |              |
# |    fps                  | 29           |
# |    iterations           | 17           |
# |    time_elapsed         | 1194         |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0065729823 |
# |    clip_fraction        | 0.054        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.174       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.01         |
# |    loss                 | 1.62         |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00266      |
# |    value_loss           | 4.65         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | -137        |
# | time/                   |             |
# |    fps                  | 29          |
# |    iterations           | 18          |
# |    time_elapsed         | 1265        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.065938585 |
# |    clip_fraction        | 0.0704      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.108      |
# |    explained_variance   | 0.987       |
# |    learning_rate        | 0.01        |
# |    loss                 | 5.12        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | 0.00358     |
# |    value_loss           | 6.63        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 142       |
# |    ep_rew_mean          | -142      |
# | time/                   |           |
# |    fps                  | 29        |
# |    iterations           | 19        |
# |    time_elapsed         | 1335      |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 4.0138617 |
# |    clip_fraction        | 0.322     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0423   |
# |    explained_variance   | 0.993     |
# |    learning_rate        | 0.01      |
# |    loss                 | 0.468     |
# |    n_updates            | 380       |
# |    policy_gradient_loss | 0.0549    |
# |    value_loss           | 0.857     |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 146        |
# |    ep_rew_mean          | -146       |
# | time/                   |            |
# |    fps                  | 29         |
# |    iterations           | 20         |
# |    time_elapsed         | 1405       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.08986857 |
# |    clip_fraction        | 0.0573     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0279    |
# |    explained_variance   | 0.887      |
# |    learning_rate        | 0.01       |
# |    loss                 | 0.909      |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.00035    |
# |    value_loss           | 11.4       |
# ----------------------------------------

# %%
#state = env.reset()
print(state)
action, _states = model.predict(state)
print(action)

state, reward, done0,t, info = env.step(action)
print(state)
print(reward)
print(done0)
print(t)
# Out:
# [-0.5193644  -0.01343038]
# 0
# [-0.53382653 -0.01446214]
# -1.0
# False
# False

# %%
episodes = 20
state = env.reset()

for episode in range(1, episodes + 1):
    state = env.reset()
    done0 = False
    t = False
    score = 0
    state = state[0]
    #print(model.predict(state))
    #print(env.step(action))
    while not (done0 | t):
        action, _states = model.predict(state)  # Use 'state' here
        #print(model.predict(state))
        state, reward, done0,t, info = env.step(action)
        #print(env.step(action))
        score += reward
        env.render()
    #print(model.predict(state))
    #print(env.step(action))
    score = score + 200
    print('Episode:{} Score:{}'.format(episode, score))
# Out:
# Episode:1 Score:26.0
# Episode:2 Score:0.0
# Episode:3 Score:21.0
# Episode:4 Score:0.0
# Episode:5 Score:26.0
# Episode:6 Score:29.0
# Episode:7 Score:26.0
# Episode:8 Score:4.0
# Episode:9 Score:27.0
# Episode:10 Score:0.0
# Episode:11 Score:0.0
# Episode:12 Score:29.0
# Episode:13 Score:25.0
# Episode:14 Score:0.0
# Episode:15 Score:0.0
# Episode:16 Score:0.0
# Episode:17 Score:0.0
# Episode:18 Score:0.0
# Episode:19 Score:27.0
# Episode:20 Score:25.0

# %%
env.close()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import gym
import numpy as np
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.vec_env import DummyVecEnv
